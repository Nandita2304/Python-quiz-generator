# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\91738\\Desktop\\project'

# %%
data = pd.read_csv('data (2).csv')

# %%
print(data)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39           88.12     1479.0
# 565    926682         M        20.13         28.25           88.12     1261.0
# 566    926954         M        16.60         28.08           88.12      858.1
# 567    927241         M        20.60         29.33           88.12     1265.0
# 568     92751         B         7.76         24.54           88.12      181.0
#
# ...

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39           88.12     1479.0
# 565    926682         M        20.13         28.25           88.12     1261.0
# 566    926954         M        16.60         28.08           88.12      858.1
# 567    927241         M        20.60         29.33           88.12     1265.0
# 568     92751         B         7.76         24.54           88.12      181.0
#
# ...

# %%
data.isnull()
# Out:
#         id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    False      False        False         False           False      False
# 1    False      False        False         False           False      False
# 2    False      False        False         False           False      False
# 3    False      False        False         False           False      False
# 4    False      False        False         False           False      False
# ..     ...        ...          ...           ...             ...        ...
# 564  False      False        False         False           False      False
# 565  False      False        False         False           False      False
# 566  False      False        False         False           False      False
# 567  False      False        False         False           False      False
# 568  False      False        False         False           False      False
#
# ...

# %%
data.isnull().sum()
# Out:
# id                         0
# diagnosis                  1
# radius_mean                2
# texture_mean               4
# perimeter_mean             3
# area_mean                  1
# smoothness_mean            1
# compactness_mean           2
# concavity_mean             1
# concave points_mean        2
# symmetry_mean              2
# fractal_dimension_mean     1
# radius_se                  1
# texture_se                 1
# perimeter_se               2
# area_se                    0
# smoothness_se              5
# compactness_se             0
# concavity_se               1
# concave points_se          1
# symmetry_se                0
# fractal_dimension_se       1
# radius_worst               0
# texture_worst              0
# perimeter_worst            2
# area_worst                 1
# smoothness_worst           0
# compactness_worst          1
# concavity_worst            1
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    2
# ...

# %%
data.notnull()
# Out:
#        id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    True       True         True          True            True       True
# 1    True       True         True          True            True       True
# 2    True       True         True          True            True       True
# 3    True       True         True          True            True       True
# 4    True       True         True          True            True       True
# ..    ...        ...          ...           ...             ...        ...
# 564  True       True         True          True            True       True
# 565  True       True         True          True            True       True
# 566  True       True         True          True            True       True
# 567  True       True         True          True            True       True
# 568  True       True         True          True            True       True
#
# ...

# %%
series1=pd.notnull(data["diagnosis"])

# %%
data[series1]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39           88.12     1479.0
# 565    926682         M        20.13         28.25           88.12     1261.0
# 566    926954         M        16.60         28.08           88.12      858.1
# 567    927241         M        20.60         29.33           88.12     1265.0
# 568     92751         B         7.76         24.54           88.12      181.0
#
# ...

# %%
ndf=data
ndf.fillna(0)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39           88.12     1479.0
# 565    926682         M        20.13         28.25           88.12     1261.0
# 566    926954         M        16.60         28.08           88.12      858.1
# 567    927241         M        20.60         29.33           88.12     1265.0
# 568     92751         B         7.76         24.54           88.12      181.0
#
# ...

# %%
data['diagnosis']=data['diagnosis'].fillna(data['diagnosis'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10552\1794096834.py in <module>
# ----> 1 data['diagnosis']=data['diagnosis'].fillna(data['diagnosis'].mean())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11122             **kwargs,
#   11123         ):
# > 11124             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11125
#   11126         setattr(cls, "mean", mean)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10692         **kwargs,
#   10693     ) -> Series | float:
# > 10694         return self._stat_function(
#   10695             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10696         )
#
# ...
